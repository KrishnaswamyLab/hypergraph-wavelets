# %%
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt

# %%
cell_protein_df = pd.read_csv('../data/MIBI/raw/cell_protein_data.csv')
patient_df = pd.read_csv('../data/MIBI/raw/patient_info.csv')

# %%
cell_protein_df
# Out:
#        unique_id  label  area  x_centroid  y_centroid  beta-tubulin  CD11b  \
# 0        0_R10C2      1   241         185           6      0.138751    0.0
# 1        1_R10C2      2   219         891           3     50.888920    0.0
# 2        2_R10C2      3   506         421           6     57.919498    0.0
# 3        3_R10C2      4   382          25           5      0.000000    0.0
# 4        4_R10C2      5   207         596           4      8.958015    0.0
# ...          ...    ...   ...         ...         ...           ...    ...
# 54984  1049_R9C4   1050   258         480         998     38.945604    0.0
# 54985  1050_R9C4   1051   544          71         996     54.562097    0.0
# 54986  1051_R9C4   1052   126         307        1000     49.100077    0.0
# 54987  1052_R9C4   1053   324         347         999     55.297113    0.0
# 54988  1053_R9C4   1054   147         706        1000     49.838060    0.0
#
#        CD11c       CD14      CD163  ...     Ki-67  LAG3  PD-1     PD-L1  \
# 0        0.0   0.000000   0.000000  ...  0.000000   0.0   0.0  0.000000
# 1        0.0   0.000000   0.000000  ...  0.000000   0.0   0.0  0.000000
# 2        0.0   0.000000   0.000000  ...  0.000000   0.0   0.0  0.000000
# 3        0.0   0.000000   0.000000  ...  0.000000   0.0   0.0  3.266732
# 4        0.0   0.000000   0.000000  ...  0.000000   0.0   0.0  0.000000
# ...      ...        ...        ...  ...       ...   ...   ...       ...
# 54984    0.0   0.000000   0.050267  ...  0.796093   0.0   0.0  0.000000
# 54985    0.0  12.824078  17.536956  ...  0.000000   0.0   0.0  0.000000
# 54986    0.0   0.000000   0.000000  ...  0.000000   0.0   0.0  0.000000
# 54987    0.0   0.000000   0.000000  ...  0.000000   0.0   0.0  0.000000
# 54988    0.0   0.000000   0.000000  ...  0.000000   0.0   0.0  0.000000
#
#        Podoplanin       SMA      SOX10     TIM-3   Vimentin     id
# 0        0.000000  0.000000   0.000000  0.000000  51.411040  R10C2
# 1        0.000000  0.000000   0.000000  0.000000  45.702071  R10C2
# 2        0.000000  1.349121   5.465880  0.000000  56.163262  R10C2
# 3        0.000000  0.000000   0.000000  0.000000  36.639569  R10C2
# 4        0.000000  0.000000  22.122374  0.000000  30.259566  R10C2
# ...           ...       ...        ...       ...        ...    ...
# 54984    0.000000  0.000000   5.122951  0.000000  38.110435   R9C4
# 54985    1.223147  0.000000   0.000000  0.068909  40.089529   R9C4
# 54986    0.000000  0.000000   0.000000  0.000000  26.630395   R9C4
# 54987    0.000000  0.000000   0.000000  0.000000  37.849359   R9C4
# 54988    0.000000  0.000000   0.000000  0.000000  27.596632   R9C4
#
# [54989 rows x 35 columns]

# %%
df = cell_protein_df[cell_protein_df['id']=='R9C4']

# %%
color_column = 'Vimentin'

scatter = plt.scatter(df['x_centroid'], 
                     df['y_centroid'], 
                     c=df[color_column], 
                     cmap='viridis',
                     alpha=0.6,
                     s=10)
plt.colorbar(scatter, label=color_column)
